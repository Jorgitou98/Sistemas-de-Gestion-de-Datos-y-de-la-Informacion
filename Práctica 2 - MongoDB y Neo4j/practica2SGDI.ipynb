# %% [markdown]
# Nombre 1: Beatriz Herguedas Pinedo
#
# Nombre 2: Jorge Villarrubia Elvira

# %% [markdown]
# # Sistemas de Gestión de Datos y de la Información
#
# ## Práctica 2
#
# - Se valorará la claridad del código y evitar redundancias o código poco eficiente; en particular se valorará lograr el resultado de las consultas mediante MongoDB minimizando el uso de Python
# - Además de las funciones que se piden se pueden añadir otras auxiliares si se necesitan, y también otros imports
# - El código debe funcionar correctamente no solo con las pruebas que vienen de ejemplo sino con cualquier otra prueba
#
#
# ### Primera parte: MongoDB
#
# Se requiere tener acceso a un servidor, ya sea arrancado en local o en la nube. Comprobar con el siguiento código si se puede acceder a él:

# %%
# cambiar si hace falta, ahora está para servidor local
#url_servidor = 'mongodb://127.0.0.1:27017/'
url_servidor = 'mongodb://127.0.0.1:27017/'

# si es en atlas será algo como
#url_servidor= "mongodb+srv://aniceto:castañas@cluster0.nubot.mongodb.net/test?retryWrites=true&w=majority"

import sys
# comprobar si pymongo está instalado, y hacerlo en otro caso
try:
    import pymongo
    print("pymongo está en el sistema!")
except ImportError as e:
    # !{sys.executable} -m pip install --upgrade --user pymongo
    import pymongo

try:
    import pprint
    print("pprint está en el sistema!")
except ImportError as e:
    # !{sys.executable} -m pip install --upgrade --user pprint
    import pprint

from pprint import pprint # para mostrar los json bonitos
from pymongo import MongoClient

# Atlas: 
#client = MongoClient("mongodb+srv://aniceto:castañas@cluster0.nubot.mongodb.net/test?retryWrites=true&w=majority")
client = MongoClient(url_servidor)

# código para ver si se ha conectado bien
try:
    s = client.server_info() # si hay error tendremos una excepción
    print("Conectado a MongoDB, versión",s["version"])
except:
    print ("Error de conexión ¿está arrancado el servidor?")
# Out:
# pymongo está en el sistema!
# pprint está en el sistema!
# Conectado a MongoDB, versión 5.0.3

# %% [markdown]
# El siguiente paso es importar los datos. Una posibilidad es bajarse el fichero de JSON e importarlo con mongoimport, pero aquí vamos a ver otra forma de hacerlo que presenta la ventaja de que nos permite trabajar con ficheros realmente grandes (no es el caso) porque hace carga "perezosa" , documento a documento, sin llegar a tener todos los documentos en memoria en ningún momento.
#
# **Ojo**: este código borrará la colección tweet de la base de datos practica2, antes de cargar el contenido, para evitar que el código sea acumulativo (un matemático diría que para que el código sea idempotente)
#
# La salida esperada
#
#     Colección tweet: 3022 documentos cargados con éxito y 0 errores

# %%
import json # para transformar la línea leida (string) a json
import urllib.request # para leer de la URL línea a línea

def carga_desde_fichero(db,fichero,coleccion):
    db[coleccion].drop() # la borramos
    exito,error = 0,0
    # cargamos los datos desde el fichero
    try:
        with urllib.request.urlopen(fichero) as f:
        
            for line in f:
                line2 = line.decode("UTF-8").replace("$","")
                res = db[coleccion].insert_one(json.loads(line2))
                if res.acknowledged:
                    exito+=1
                else:
                    error+=1
        print(f"Colección {coleccion}: {exito} documentos cargados con éxito y {error} errores")
    except urllib.error.URLError as e:
        print(e.reason)
   
            
db = client.practica2
fichero_tweets = "https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/ctweet.json"
carga_desde_fichero(db,fichero_tweets,"tweet")
# Out:
# Colección tweet: 3022 documentos cargados con éxito y 0 errores

# %% [markdown]
# **Ejercicio 1** Escribir una función `num_replicas` que devuelva cuántos tweets son réplicas (clave `in_reply_to_screen_name`) a un usuario.
#
# - *Nombre*: `num_replicas`
# - *Parámetros de entrada*:
#     - `db`: el acceso a una base de datos que se asume incluye una colección `tweet`de tweets
#     - `usuario`: screen_name de un usuario
#
# - *Devuelve*: número de tweets que son réplicas al usuario (un entero mayor o igual que 0)

# %%
# solución
def num_replicas(db,usuario):
    return db.tweet.count_documents({'reply': True, 'in_reply_to_screen_name': usuario})

### para probar el código
print(num_replicas(db,"JoeBiden"),"réplicas a JoeBiden")
print(num_replicas(db,"realDonaldTrump"),"réplicas a realDonaldTrump")
# Out:
# 25 réplicas a JoeBiden
# 204 réplicas a realDonaldTrump

# %% [markdown]
# **Ejercicio 2** Escribir una función `num_menciones` para conocer el número de tweets que nombran (examinar `user_mentions`) a un usuario dado su screen_name
# - *Nombre*: `num_menciones`
# - *Parámetros de entrada*:
#     - `db`: el acceso a una base de datos que se asume incluye una colección `tweet`de tweets
#     - `usuario`: screen_name de un usuario
#
# - *Devuelve*: número de tweets que mencionan al usuario (un entero mayor o igual a 0)

# %%
list(db.tweet.find({"user_mentions":{"$exists":1}}))
# Out:
# [{'_id': '1188094205299703809',
#   'userid': '620571475',
#   'screen_name': 'DanScavino',
#   'created_at': {'date': '2019-10-26T14:05:06Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'und',
#   'reply': False,
#   'RT': False,
#   'text': 'https://t.co/iAbQ5Ip3bW https://t.co/GHMeQQqw1x',
#   'nreplyin': 0,
#   'nquotein': 35,
#   'nRTin': 0},
#  {'_id': '1188453559391666178',
#   'userid': '108416118',
#   'screen_name': 'PhillyPartTwo',
#   'created_at': {'date': '2019-10-27T13:53:03Z'},
#   'hashtags': [{'text': 'judges', 'indices': [45, 52]},
#    {'text': 'Trump', 'indices': [91, 97]},
#    {'text': 'evangelical', 'indices': [102, 114]}],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-75.04539574, 40.16216216]},
#   'reply': False,
#   'RT': False,
#   'text': "Unqualified ultra-conservative young federal #judges that serve no purpose but to push the #Trump and #evangelical agenda who will preside for forty years will be Trump's lasting legacy over anything else. His bigotry and misogyny will be the rule of law for generations. https://t.co/LzNNJKNaiK",
#   'nreplyin': 0,
#   'nquotein': 1,
#   'nRTin': 0},
#  {'_id': '1190057966520668162',
#   'userid': '24787367',
#   'screen_name': 'LionelMedia',
#   'created_at': {'date': '2019-11-01T00:08:24Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [27, 43]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Retweet if you stand with \u2066@realDonaldTrump\u2069! https://t.co/3ju6dzvO2S',
#   'nreplyin': 49,
#   'nquotein': 73,
#   'nRTin': 1373},
#  {'_id': '1190444836505182208',
#   'userid': '2954922809',
#   'screen_name': 'rdjkazmi',
#   'created_at': {'date': '2019-11-02T01:45:41Z'},
#   'hashtags': [{'text': 'BeatHimLikeADrum', 'indices': [87, 104]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'TheDemocrats',
#     'name': 'The Democrats',
#     'id': 14377605,
#     'id_str': '14377605',
#     'indices': [26, 39]},
#    {'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [77, 86]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'A divided house but still @TheDemocrats. That said, I’m “Ridin’ with Biden”! @JoeBiden #BeatHimLikeADrum #IowaForBiden #Dems2020 @schultzohio @ClaudieEsmee https://t.co/RuEpFcy064',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1196575471258996741',
#   'userid': '1088729740930936832',
#   'screen_name': 'Cabdull13822073',
#   'created_at': {'date': '2019-11-18T23:46:38Z'},
#   'hashtags': [{'text': 'Trump', 'indices': [60, 66]},
#    {'text': 'thesingingtrump', 'indices': [67, 83]},
#    {'text': 'NewYorkCity', 'indices': [84, 96]},
#    {'text': 'WashingtonDC', 'indices': [97, 110]}],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [28.7645423, 41.0550449]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': "I'm Late but, he is the lost twin of the Halloween costume. #Trump #thesingingtrump #NewYorkCity #WashingtonDC #WhiteHouse #politics #LateLateShow #EllenDeGeneres #BBCWorkLife #trtworld #HongKong #America #NEW #Headline #funny #Trump2020  #imamoğlu #TrendingInChina #TrendingNow https://t.co/UE5fgtVtse",
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1224955461310599168',
#   'userid': '39562650',
#   'screen_name': 'BLITZTHEENT',
#   'created_at': {'date': '2020-02-05T07:18:35Z'},
#   'hashtags': [{'text': 'ATLANTA', 'indices': [28, 36]},
#    {'text': 'weedporn', 'indices': [37, 46]},
#    {'text': 'weed', 'indices': [47, 52]},
#    {'text': 'weedclan', 'indices': [53, 62]},
#    {'text': 'rawlife247', 'indices': [64, 75]},
#    {'text': 'rawlife', 'indices': [76, 84]},
#    {'text': 'ganja', 'indices': [85, 91]},
#    {'text': 'BHOssBytcheZ', 'indices': [93, 106]}],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-84.4125, 33.5726]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'clockwiserami\nFridayHighDay #ATLANTA\n#weedporn #weed #weedclan \n#rawlife247 #rawlife #ganja \n#BHOssBytcheZ #february\n#trump #highsociety #hightimes \n#potheadsociety #pothead #brooklyn\n#stonernation #stoned… https://t.co/XmrkfIG2WK',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1229634552022421504',
#   'userid': '245963716',
#   'screen_name': 'TiffanyATrump',
#   'created_at': {'date': '2020-02-18T05:11:37Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [46, 62]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Happy Presidents’ Day to my incredible father @realDonaldTrump and our country’s great leaders of the past and present ❤️🤍💙 #PresidentsDay https://t.co/4kmc7pbqWd',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 2},
#  {'_id': '1271684260387270656',
#   'userid': '32532994',
#   'screen_name': 'dannyhellman',
#   'created_at': {'date': '2020-06-13T06:02:09Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [36, 45]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Hadn\'t seen this one before. Here\'s @JoeBiden defending his crime bill by suggesting that crack users deserved harsher sentencing than "someone in a beautiful neighborhood like this sniffing a line of cocaine." #NeverBiden #DemExit2020 https://t.co/umjoQp5zZ6',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1272350470644871169',
#   'userid': '245963716',
#   'screen_name': 'TiffanyATrump',
#   'created_at': {'date': '2020-06-15T02:09:25Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [20, 36]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Happy Birthday Dad! @realdonaldtrump I’m so grateful for your love and guidance. I love you! https://t.co/QMl6KZiMEf',
#   'nreplyin': 1,
#   'nquotein': 1,
#   'nRTin': 2},
#  {'_id': '1272352441422536705',
#   'userid': '245963716',
#   'screen_name': 'TiffanyATrump',
#   'created_at': {'date': '2020-06-15T02:17:15Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [20, 36]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Happy Birthday Dad! @realDonaldTrump I’m so grateful for your love and guidance. I love you! https://t.co/la0yz2mkDK',
#   'nreplyin': 1,
#   'nquotein': 0,
#   'nRTin': 7},
#  {'_id': '1274823395528650752',
#   'userid': '245963716',
#   'screen_name': 'TiffanyATrump',
#   'created_at': {'date': '2020-06-21T21:55:57Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [24, 40]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-77.03649486, 38.89769958]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Happy Father’s Day Dad! @realdonaldtrump I love you and I’m so grateful for you! Thank you for your constant love, guidance and for always believing in me! @ The White House https://t.co/Q94DbCobkG',
#   'nreplyin': 2,
#   'nquotein': 0,
#   'nRTin': 2},
#  {'_id': '1274823885607833600',
#   'userid': '245963716',
#   'screen_name': 'TiffanyATrump',
#   'created_at': {'date': '2020-06-21T21:57:54Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [24, 40]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Happy Father’s Day Dad! @realdonaldtrump I love you and I’m so grateful for you! Thank you for your constant love, guidance and for always believing in me! https://t.co/5cmIbXFvEN',
#   'nreplyin': 6,
#   'nquotein': 0,
#   'nRTin': 9},
#  {'_id': '1289647652804554752',
#   'userid': '140623364',
#   'screen_name': '1_Tru_G',
#   'created_at': {'date': '2020-08-01T19:42:15Z'},
#   'hashtags': [{'text': 'tiktokban', 'indices': [81, 91]},
#    {'text': 'trump', 'indices': [92, 98]},
#    {'text': 'karen', 'indices': [99, 105]},
#    {'text': 'covid', 'indices': [106, 112]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'BlakePavey',
#     'name': 'Blake Pavey',
#     'id': 918218955914801152,
#     'id_str': '918218955914801152',
#     'indices': [38, 49]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-80.93224582, 35.2972973]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'LMFAAAAOOOO..THIS IS FUNNY!!!!🤣🤣** RT @BlakePavey: GLOBAL UPDATE: USA TIKTOK BAN #tiktokban #trump #karen #covid (Insta/YouTube - @blakepavey) https://t.co/2sDynVaHVZ',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1299881504835801088',
#   'userid': '25125132',
#   'screen_name': 'ComedianKD',
#   'created_at': {'date': '2020-08-30T01:27:56Z'},
#   'hashtags': [{'text': 'childtraffickingexposed', 'indices': [56, 80]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'Facebook',
#     'name': 'Facebook',
#     'id': 2425151,
#     'id_str': '2425151',
#     'indices': [41, 50]},
#    {'screen_name': 'MarkZuckerbeg',
#     'name': 'Mark Zuckerbeg',
#     'id': 375900204,
#     'id_str': '375900204',
#     'indices': [95, 109]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'So please share... if you type BAGETS on @facebook alot #childtraffickingexposed sites pop up! @MarkZuckerbeg where are you on this?! @POTUS @IvankaTrump @RealEricTeump we need this stopped!! #parenting #kids you too @JoeBiden wtf https://t.co/KMRLFR7wbM',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1302216521268236289',
#   'userid': '108193922',
#   'screen_name': 'FrStephenImb',
#   'created_at': {'date': '2020-09-05T12:06:27Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '... the greatest destroyer of peace today is abortion, because it is a war against the child, a direct killing of the innocent child, murder by the mother herself.” @JoeBiden #scandal @realDonaldTrump #newlincoln #abortionismurder #catholic https://t.co/b6E79fQxiJ',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1303418241730183168',
#   'userid': '245963716',
#   'screen_name': 'TiffanyATrump',
#   'created_at': {'date': '2020-09-08T19:41:39Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '“This election, I urge you to transcend political boundaries — to make your judgment based on results and not rhetoric. This is a fight for freedom versus oppression, for opportunity versus stagnation, a fight to keep America true to America.” - TT https://t.co/Z2dsfvFCiJ',
#   'nreplyin': 639,
#   'nquotein': 4,
#   'nRTin': 0},
#  {'_id': '1305934530902138886',
#   'userid': '78685709',
#   'screen_name': 'JackBrewerBSI',
#   'created_at': {'date': '2020-09-15T18:20:29Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'WhiteHouse',
#     'name': 'The White House',
#     'id': 822215673812119553,
#     'id_str': '822215673812119553',
#     'indices': [33, 44]},
#    {'screen_name': 'FLOTUS',
#     'name': 'Melania Trump',
#     'id': 818876014390603776,
#     'id_str': '818876014390603776',
#     'indices': [61, 68]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': True,
#   'RT': False,
#   'text': 'Such an honor to be guest of the @WhiteHouse and the amazing @FLOTUS - My family and I will continue to support @realDonaldTrump tireless efforts to bring resources and solutions to issues effecting underserved African Americans across our nation. #GloryToGod',
#   'nreplyin': 1,
#   'nquotein': 0,
#   'nRTin': 2},
#  {'_id': '1307559456604065793',
#   'userid': '620571475',
#   'screen_name': 'DanScavino',
#   'created_at': {'date': '2020-09-20T05:57:22Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'ColbyCovMMA',
#     'name': 'Colby Covington',
#     'id': 442456291,
#     'id_str': '442456291',
#     'indices': [16, 28]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [62, 78]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Congratulations @ColbyCovMMA! Great moment tonight when POTUS @realDonaldTrump calls him in the middle of a live interview, after his BIG W — love it! #UFCVegas11 #MAGA🇺🇸🦅 https://t.co/x3AweYoeif',
#   'nreplyin': 20,
#   'nquotein': 7,
#   'nRTin': 81},
#  {'_id': '1308745607344009216',
#   'userid': '78685709',
#   'screen_name': 'JackBrewerBSI',
#   'created_at': {'date': '2020-09-23T12:30:42Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': True,
#   'RT': False,
#   'text': 'This is unbelievable.. https://t.co/aIy2P1nVjn',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1309112603352985600',
#   'userid': '78685709',
#   'screen_name': 'JackBrewerBSI',
#   'created_at': {'date': '2020-09-24T12:49:01Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': True,
#   'RT': False,
#   'text': 'Since 2016, the SEC/FBI has used 10 tax payer funded lawyers to shake me down over a 35,000 civil trade dispute, all because I support @realDonaldTrump. While ignoring @JoeBiden family schemes to bring billions from China, UKR &amp; Russia. If I was a @TheDemocrats I’d blame RACISM! https://t.co/5rwMrGihcl',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1309555721965453312',
#   'userid': '620571475',
#   'screen_name': 'DanScavino',
#   'created_at': {'date': '2020-09-25T18:09:49Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': True,
#   'RT': False,
#   'text': 'President Trump on pre-existing conditions, yesterday:\n\n“The historic action I took today includes the first-ever executive order to affirm it is the official policy of the U.S. Government to protect patients with pre-existing conditions.” @realDonaldTrump https://t.co/g5mlZHoPTh https://t.co/NwzjcZ88oT',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 12},
#  {'_id': '1309640769314213888',
#   'userid': '620571475',
#   'screen_name': 'DanScavino',
#   'created_at': {'date': '2020-09-25T23:47:46Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [97, 113]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Florida this morning, Georgia this afternoon, Washington, D.C. this evening, and now — President @realDonaldTrump departing Washington, D.C. for a MAGA Rally in Newport News, Virginia! Wheels up shortly! #MAGA🇺🇸🦅 https://t.co/XxFKpnw4ms',
#   'nreplyin': 13,
#   'nquotein': 7,
#   'nRTin': 24},
#  {'_id': '1310404142523973632',
#   'userid': '23951440',
#   'screen_name': 'BGOnTheScene',
#   'created_at': {'date': '2020-09-28T02:21:08Z'},
#   'hashtags': [{'text': 'Louisville', 'indices': [81, 92]},
#    {'text': 'LouisvilleProtests', 'indices': [93, 112]}],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Black Lives Matter march making its way through downtown Louisville this evening #Louisville #LouisvilleProtests #BlackLivesMatter https://t.co/AGiD6RFDSC',
#   'nreplyin': 0,
#   'nquotein': 1,
#   'nRTin': 0},
#  {'_id': '1310671475091873792',
#   'userid': '822491959805825027',
#   'screen_name': 'DaysLeft4Trump',
#   'created_at': {'date': '2020-09-28T20:03:25Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'WhiteHouse',
#     'name': 'The White House',
#     'id': 822215673812119553,
#     'id_str': '822215673812119553',
#     'indices': [0, 11]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [12, 28]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-77.0387238, 38.8976805]},
#   'reply': True,
#   'in_reply_to_user_id_str': '822215673812119553',
#   'in_reply_to_status_id_str': '1310671338634444802',
#   'in_reply_to_screen_name': 'WhiteHouse',
#   'quote': False,
#   'RT': False,
#   'text': '@WhiteHouse @realDonaldTrump 3 Months, 22 Days, 20 Hours, 57 Minutes, and 1 Second',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1310791096138706945',
#   'userid': '25073877',
#   'screen_name': 'realDonaldTrump',
#   'created_at': {'date': '2020-09-29T03:58:45Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'CNN',
#     'name': 'CNN',
#     'id': 759251,
#     'id_str': '759251',
#     'indices': [14, 18]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Now Fake News @CNN is actually reporting that I wanted my daughter, Ivanka, to run with me as my Vice President in 2016 Election. Wrong and totally ridiculous. These people are sick!',
#   'nreplyin': 840,
#   'nquotein': 14,
#   'nRTin': 0},
#  {'_id': '1310918927527149569',
#   'userid': '620571475',
#   'screen_name': 'DanScavino',
#   'created_at': {'date': '2020-09-29T12:26:42Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'und',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'https://t.co/yuN1BsBA5M',
#   'nreplyin': 0,
#   'nquotein': 4,
#   'nRTin': 0},
#  {'_id': '1310938491883327493',
#   'userid': '63335631',
#   'screen_name': 'Joy_Villa',
#   'created_at': {'date': '2020-09-29T13:44:27Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [10, 26]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'President @realDonaldTrump has received THREE separate Nobel Peace Prize nominations for his foreign policy! INCREDIBLE!',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1310970857930489859',
#   'userid': '25073877',
#   'screen_name': 'realDonaldTrump',
#   'created_at': {'date': '2020-09-29T15:53:03Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': True,
#   'RT': False,
#   'text': 'A GREAT HONOR, THANK YOU!!',
#   'nreplyin': 385,
#   'nquotein': 7,
#   'nRTin': 2272},
#  {'_id': '1311032604351705092',
#   'userid': '620571475',
#   'screen_name': 'DanScavino',
#   'created_at': {'date': '2020-09-29T19:58:25Z'},
#   'hashtags': [{'text': 'Debates2020', 'indices': [32, 44]},
#    {'text': 'MAGA', 'indices': [45, 50]}],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Wheels down in Cleveland, Ohio! #Debates2020 #MAGA🇺🇸🦅 https://t.co/mA6lrrWSd5',
#   'nreplyin': 3,
#   'nquotein': 12,
#   'nRTin': 0},
#  {'_id': '1311051607442944007',
#   'userid': '25073877',
#   'screen_name': 'realDonaldTrump',
#   'created_at': {'date': '2020-09-29T21:13:56Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Just arrived in the Great State of Ohio. Real Polls have us leading by even more than 2016. With Biden being against Fracking (Energy &amp; Jobs) &amp; your Second Amendment, we should be in very good shape!',
#   'nreplyin': 4842,
#   'nquotein': 82,
#   'nRTin': 0},
#  {'_id': '1311051647687307264',
#   'userid': '25073877',
#   'screen_name': 'realDonaldTrump',
#   'created_at': {'date': '2020-09-29T21:14:05Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Wow. Won’t let Poll Watchers &amp; Security into Philadelphia Voting Places. There is only one reason why. Corruption!!! Must have a fair Election.',
#   'nreplyin': 6440,
#   'nquotein': 434,
#   'nRTin': 0},
#  {'_id': '1311057015591104514',
#   'userid': '131745292',
#   'screen_name': 'lizamileshappy',
#   'created_at': {'date': '2020-09-29T21:35:25Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [0, 9]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': "@JoeBiden say it isn't so!\nhttps://t.co/26aL1rjo0d",
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311061369219952641',
#   'userid': '23951440',
#   'screen_name': 'BGOnTheScene',
#   'created_at': {'date': '2020-09-29T21:52:43Z'},
#   'hashtags': [{'text': 'Debates2020', 'indices': [69, 81]},
#    {'text': 'DebateTuesday', 'indices': [82, 96]},
#    {'text': 'Cleveland', 'indices': [97, 107]}],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Military Police out on the streets of Cleveland for tonight’s debate #Debates2020 #DebateTuesday #Cleveland https://t.co/N8kvKEf3bs',
#   'nreplyin': 1,
#   'nquotein': 1,
#   'nRTin': 0},
#  {'_id': '1311066006945763330',
#   'userid': '45406060',
#   'screen_name': 'H2O_MaggieO',
#   'created_at': {'date': '2020-09-29T22:11:09Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-86.3624, 43.4154]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Let’s try this again... although I’m sure the person who stole them would love to know I made a donation to the #bidenharris2020 campaign along with buying more signs #votehimout @joebiden @kamalaharris #forthewin https://t.co/ORcjGEOe3c',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311066917130690561',
#   'userid': '93288759',
#   'screen_name': 'twright55',
#   'created_at': {'date': '2020-09-29T22:14:46Z'},
#   'hashtags': [{'text': 'BREAKING', 'indices': [0, 9]}],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': "#BREAKING: The Director of National Intelligence Ratcliffe has declassified information indicating that former #Obama's administration knew about #HillaryClinton was attempting to tie #Trump to Russia and distract from her email scandal in 2016. He plans to brief Congress ASAP.",
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311073195282149376',
#   'userid': '24640148',
#   'screen_name': 'mastahanksta',
#   'created_at': {'date': '2020-09-29T22:39:42Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [0, 9]}],
#   'lang': 'en',
#   'reply': True,
#   'in_reply_to_user_id_str': '939091',
#   'in_reply_to_status_id_str': '1310998525321383944',
#   'in_reply_to_screen_name': 'JoeBiden',
#   'quote': False,
#   'RT': False,
#   'text': '@JoeBiden Biden is going to be the President fir 2021 new beginnings!',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311074602244866058',
#   'userid': '23951440',
#   'screen_name': 'BGOnTheScene',
#   'created_at': {'date': '2020-09-29T22:45:18Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'A woman discusses being arrested for protesting in both Columbus and Louisville, and how this impacts one’s ability to be out there on the front lines every night #Debates2020\xa0 #DebateTuesday #Cleveland https://t.co/FIuNA13CXx',
#   'nreplyin': 0,
#   'nquotein': 1,
#   'nRTin': 0},
#  {'_id': '1311075070148657152',
#   'userid': '161605938',
#   'screen_name': 'MyParExcellence',
#   'created_at': {'date': '2020-09-29T22:47:09Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [32, 48]},
#    {'screen_name': 'GenFlynn',
#     'name': 'General Flynn',
#     'id': 240454812,
#     'id_str': '240454812',
#     'indices': [49, 58]},
#    {'screen_name': 'SidneyPowell1',
#     'name': 'Sidney Powell 🇺🇸⭐⭐⭐',
#     'id': 586707638,
#     'id_str': '586707638',
#     'indices': [59, 73]},
#    {'screen_name': 'ALT_DOJ',
#     'name': 'ALT DOJ',
#     'id': 824450140131975168,
#     'id_str': '824450140131975168',
#     'indices': [74, 82]},
#    {'screen_name': 'KerriKupecDOJ',
#     'name': 'Kerri Kupec DOJ',
#     'id': 1062465792212717574,
#     'id_str': '1062465792212717574',
#     'indices': [83, 97]},
#    {'screen_name': 'DOJPH',
#     'name': 'Department of Justice (DOJ)',
#     'id': 485403686,
#     'id_str': '485403686',
#     'indices': [98, 104]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': True,
#   'RT': False,
#   'text': 'Isaiah 5:20 at its worst case!  @realDonaldTrump @GenFlynn @SidneyPowell1 @ALT_DOJ @KerriKupecDOJ @DOJPH @thevivafrei @marklevinshow @Barnes_Law @JudgeJeanine @TuckerCarlson @RichardGrenell @greggutfeld @IngrahamAngle',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311081076924669953',
#   'userid': '826549394606546946',
#   'screen_name': 'LumberjackHill',
#   'created_at': {'date': '2020-09-29T23:11:02Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-81.03876114, 34.01119057]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '@realdonaldtrump lied on 12-Jun-2017 saying "Great success, including MS-13. They\'re being thrown out in record numbers and rapidly. And they\'re being depleted. They\'ll all be gone pretty soon."  #RepublicansAgainstTrump',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311082919461564416',
#   'userid': '822491959805825027',
#   'screen_name': 'DaysLeft4Trump',
#   'created_at': {'date': '2020-09-29T23:18:21Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'PATrumpVictory',
#     'name': 'Pennsylvania Trump Victory',
#     'id': 1017871914914721799,
#     'id_str': '1017871914914721799',
#     'indices': [0, 15]},
#    {'screen_name': 'Mike_Pence',
#     'name': 'Mike Pence',
#     'id': 22203756,
#     'id_str': '22203756',
#     'indices': [16, 27]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [28, 44]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-77.0387238, 38.8976805]},
#   'reply': True,
#   'in_reply_to_user_id_str': '1017871914914721799',
#   'in_reply_to_status_id_str': '1311078153146609664',
#   'in_reply_to_screen_name': 'PATrumpVictory',
#   'quote': False,
#   'RT': False,
#   'text': '@PATrumpVictory @Mike_Pence @realDonaldTrump 3 Months, 21 Days, 17 Hours, 41 Minutes, and 53 Seconds',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311083380046401536',
#   'userid': '50925602',
#   'screen_name': 'HakimBe',
#   'created_at': {'date': '2020-09-29T23:20:11Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [0, 9]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '@JoeBiden Team, here\'e a freebie. When he tries to pivot on his "tax file" dysfunction and says you want to raise taxes (only on those making more than 400K) ... say this, "We\'d never have to raise taxes in this country if \'patriots\' like you didn\'t dodge\'em." #TaxDodger',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311084580426985472',
#   'userid': '23951440',
#   'screen_name': 'BGOnTheScene',
#   'created_at': {'date': '2020-09-29T23:24:57Z'},
#   'hashtags': [{'text': 'Debates2020', 'indices': [40, 52]},
#    {'text': 'DebateTuesday', 'indices': [54, 68]},
#    {'text': 'Cleveland', 'indices': [69, 79]}],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '“F*** Donald Trump” chants on the march #Debates2020\xa0 #DebateTuesday #Cleveland https://t.co/BB2WmbOfCX',
#   'nreplyin': 0,
#   'nquotein': 1,
#   'nRTin': 0},
#  {'_id': '1311086812472004608',
#   'userid': '822491959805825027',
#   'screen_name': 'DaysLeft4Trump',
#   'created_at': {'date': '2020-09-29T23:33:49Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'WhiteHouse',
#     'name': 'The White House',
#     'id': 822215673812119553,
#     'id_str': '822215673812119553',
#     'indices': [0, 11]},
#    {'screen_name': 'USDA',
#     'name': 'Dept. of Agriculture',
#     'id': 61853389,
#     'id_str': '61853389',
#     'indices': [12, 17]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [18, 34]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-77.0387238, 38.8976805]},
#   'reply': True,
#   'in_reply_to_user_id_str': '822215673812119553',
#   'in_reply_to_status_id_str': '1311086701561995265',
#   'in_reply_to_screen_name': 'WhiteHouse',
#   'quote': False,
#   'RT': False,
#   'text': '@WhiteHouse @USDA @realDonaldTrump 3 Months, 21 Days, 17 Hours, 26 Minutes, and 31 Seconds',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1311089122531049474',
#   'userid': '108416118',
#   'screen_name': 'PhillyPartTwo',
#   'created_at': {'date': '2020-09-29T23:43:00Z'},
#   'hashtags': [{'text': 'Trump', 'indices': [20, 26]},
#    {'text': 'Debates2020', 'indices': [59, 71]},
#    {'text': 'Debates', 'indices': [72, 80]},
#    {'text': 'PresidentialDebate', 'indices': [81, 100]},
#    {'text': 'Debate', 'indices': [101, 108]}],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': True,
#   'RT': False,
#   'text': "They're mad because #Trump can't even afford Turkey Hill. \n#Debates2020 #Debates #PresidentialDebate #Debate",
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311092035697471489',
#   'userid': '24787367',
#   'screen_name': 'LionelMedia',
#   'created_at': {'date': '2020-09-29T23:54:34Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'What are you thinking right now regarding the upcoming debate?',
#   'nreplyin': 1,
#   'nquotein': 1,
#   'nRTin': 0},
#  {'_id': '1311095042891812866',
#   'userid': '24787367',
#   'screen_name': 'LionelMedia',
#   'created_at': {'date': '2020-09-30T00:06:31Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '@realDonaldTrump must never answer any question but make a speech every time he has the chance.',
#   'nreplyin': 1,
#   'nquotein': 1,
#   'nRTin': 9},
#  {'_id': '1311096410994028544',
#   'userid': '16263931',
#   'screen_name': 'MikeKillmon',
#   'created_at': {'date': '2020-09-30T00:11:58Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [12, 21]},
#    {'screen_name': 'MariahCarey',
#     'name': 'Mariah Carey',
#     'id': 19248106,
#     'id_str': '19248106',
#     'indices': [57, 69]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'I know that @JoeBiden is gonna MAKE IT HAPPEN!!!! 💙🇺🇸 cc @MariahCarey https://t.co/4s6gDkVV2D',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311096449292218368',
#   'userid': '3360903167',
#   'screen_name': 'joshuatowevoice',
#   'created_at': {'date': '2020-09-30T00:12:07Z'},
#   'hashtags': [{'text': 'superbowl', 'indices': [18, 28]},
#    {'text': 'nyc', 'indices': [29, 33]},
#    {'text': 'trump', 'indices': [35, 41]},
#    {'text': 'bidenharris2020', 'indices': [42, 58]},
#    {'text': 'lgbtq', 'indices': [59, 65]},
#    {'text': 'cnn', 'indices': [66, 70]},
#    {'text': 'instagay', 'indices': [71, 80]},
#    {'text': 'hope', 'indices': [81, 86]},
#    {'text': 'drumptrump', 'indices': [87, 98]},
#    {'text': 'riseup', 'indices': [99, 106]}],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-73.9675, 40.7779]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Getting ready for #superbowl #nyc  #trump #bidenharris2020 #lgbtq #cnn #instagay #hope #drumptrump #riseup #thisisus #nytimes #love #goodbyetrump @ Manhattan, New York https://t.co/YGAQyZkKdq',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311101607283752962',
#   'userid': '822491959805825027',
#   'screen_name': 'DaysLeft4Trump',
#   'created_at': {'date': '2020-09-30T00:32:36Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'Mike_Pence',
#     'name': 'Mike Pence',
#     'id': 22203756,
#     'id_str': '22203756',
#     'indices': [0, 11]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [12, 28]},
#    {'screen_name': 'WhiteHouse',
#     'name': 'The White House',
#     'id': 822215673812119553,
#     'id_str': '822215673812119553',
#     'indices': [29, 40]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-77.0387238, 38.8976805]},
#   'reply': True,
#   'in_reply_to_user_id_str': '22203756',
#   'in_reply_to_status_id_str': '1311101462642999297',
#   'in_reply_to_screen_name': 'Mike_Pence',
#   'quote': False,
#   'RT': False,
#   'text': '@Mike_Pence @realDonaldTrump @WhiteHouse 3 Months, 21 Days, 16 Hours, 27 Minutes, and 52 Seconds',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311102510724251649',
#   'userid': '37174314',
#   'screen_name': 'Mdepaul76',
#   'created_at': {'date': '2020-09-30T00:36:12Z'},
#   'hashtags': [{'text': 'bidenharris2020', 'indices': [36, 52]},
#    {'text': 'voteblue2020', 'indices': [53, 66]},
#    {'text': 'dumptrump', 'indices': [67, 77]},
#    {'text': 'enhancethis', 'indices': [78, 90]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [26, 35]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-82.7672, 28.0777]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'I’m ready ! Let’s do this @joebiden #bidenharris2020 #voteblue2020 #dumptrump #enhancethis @ Palm Harbor, Florida https://t.co/eEU3foYdVq',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311104782556442625',
#   'userid': '24787367',
#   'screen_name': 'LionelMedia',
#   'created_at': {'date': '2020-09-30T00:45:13Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'You’re about to witness polemic savagery. Unyielding and unrelenting brutality in the name of liberty and truth. Go get him, @realDonaldTrump. https://t.co/muuGxVmbte',
#   'nreplyin': 1,
#   'nquotein': 0,
#   'nRTin': 2},
#  {'_id': '1311105904734015488',
#   'userid': '24515539',
#   'screen_name': 'shiffy64',
#   'created_at': {'date': '2020-09-30T00:49:41Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'the',
#     'name': 'Тајлер',
#     'id': 25668422,
#     'id_str': '25668422',
#     'indices': [11, 15]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': True,
#   'RT': False,
#   'text': 'Fact check @the truth https://t.co/jN0K0m0ecA',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1311107752236740610',
#   'userid': '826549394606546946',
#   'screen_name': 'LumberjackHill',
#   'created_at': {'date': '2020-09-30T00:57:01Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-81.38340354, 28.54389942]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '@realdonaldtrump lied on 03-Nov-2018 saying "We\'ve taken the toughest ever action to crack down on China\'s very abusive trade practices, and now they\'re paying big tariffs on 250 billion..." #RepublicansForBiden',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311108391696302080',
#   'userid': '2347105118',
#   'screen_name': 'RamonDelBarrio',
#   'created_at': {'date': '2020-09-30T00:59:34Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [0, 9]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-121.4927, 38.5763]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '@joebiden Let’s be clear about our agenda as Americans and for Humanity! We already know what he has done ! #bidenharris2020 @ California https://t.co/QnxLtKw9Iy',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311108879988727817',
#   'userid': '824310413030408192',
#   'screen_name': 'lcplpulido',
#   'created_at': {'date': '2020-09-30T01:01:30Z'},
#   'hashtags': [{'text': 'debate', 'indices': [21, 28]},
#    {'text': 'president', 'indices': [29, 39]},
#    {'text': 'presidentialelection', 'indices': [40, 61]},
#    {'text': 'presidentialdebate', 'indices': [62, 81]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [11, 20]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-118.2445, 34.0564]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '😂😂😂 get em @joebiden #debate #president #presidentialelection #presidentialdebate @ Los Angeles, California https://t.co/Pv3SFifAZP',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311109053490368517',
#   'userid': '76188884',
#   'screen_name': 'luisdvalentin',
#   'created_at': {'date': '2020-09-30T01:02:12Z'},
#   'hashtags': [{'text': 'presidentialdebate', 'indices': [50, 69]},
#    {'text': 'presidentialdebate2020', 'indices': [70, 93]},
#    {'text': 'debate', 'indices': [94, 101]},
#    {'text': 'election', 'indices': [102, 111]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [21, 30]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [31, 47]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-95.3694, 29.7602]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Are you watching???? @joebiden @realdonaldtrump \n\n#presidentialdebate #presidentialdebate2020 #debate #election #elections2020 #president #presidentialelection @ Houston, Texas https://t.co/xCTLBeBpUl',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311109075539820544',
#   'userid': '24787367',
#   'screen_name': 'LionelMedia',
#   'created_at': {'date': '2020-09-30T01:02:17Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [6, 22]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Watch @realDonaldTrump flip Biden the Malocchio.',
#   'nreplyin': 1,
#   'nquotein': 0,
#   'nRTin': 3},
#  {'_id': '1311109631972966402',
#   'userid': '1543535304',
#   'screen_name': 'BdexEntz',
#   'created_at': {'date': '2020-09-30T01:04:30Z'},
#   'hashtags': [{'text': 'joebiden', 'indices': [59, 68]},
#    {'text': 'trump', 'indices': [89, 95]}],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-0.13355317, 51.49594393]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Can’t believe am watching this America 🇺🇸 president debate #joebiden vs racist president #trump \n\n#bdexentertainment #bdextv @ Westminster https://t.co/vjSkarSTdP',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311109712532910080',
#   'userid': '486044893',
#   'screen_name': 'DJWarrenYoung',
#   'created_at': {'date': '2020-09-30T01:04:49Z'},
#   'hashtags': [{'text': 'Live', 'indices': [0, 5]},
#    {'text': 'Trump', 'indices': [13, 19]},
#    {'text': 'Vote', 'indices': [96, 101]},
#    {'text': 'Online', 'indices': [102, 109]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'FoxBusiness',
#     'name': 'FOX Business',
#     'id': 56413858,
#     'id_str': '56413858',
#     'indices': [83, 95]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': "#Live: First #Trump-Biden presidential debate moderated by Fox News' Chris Wallace @FoxBusiness #Vote #Online #Virtual #Money #Bitcoin #Q #MAGA #BLOCKCHAiN #OperationWarpSpeed #Covid19 #Vaccine #FREEDOM #FreeRoss! https://t.co/ODnKY0DUYW via @YouTube",
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311109832854786049',
#   'userid': '1082814843642630144',
#   'screen_name': 'CASinCHI',
#   'created_at': {'date': '2020-09-30T01:05:18Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'maddow',
#     'name': 'Rachel Maddow MSNBC',
#     'id': 16129920,
#     'id_str': '16129920',
#     'indices': [32, 39]},
#    {'screen_name': 'MSNBC',
#     'name': 'MSNBC',
#     'id': 2836421,
#     'id_str': '2836421',
#     'indices': [40, 46]},
#    {'screen_name': 'rufusgifford',
#     'name': 'Rufus Gifford',
#     'id': 25896607,
#     'id_str': '25896607',
#     'indices': [47, 60]},
#    {'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [61, 70]},
#    {'screen_name': 'TheDemocrats',
#     'name': 'The Democrats',
#     'id': 14377605,
#     'id_str': '14377605',
#     'indices': [71, 84]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-87.632496, 41.883222]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Getting ready for Debate Night!\n@maddow @msnbc @rufusgifford @joebiden @thedemocrats @ Chicago, Illinois https://t.co/9O9mjocbqv',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311111835001655298',
#   'userid': '63335631',
#   'screen_name': 'Joy_Villa',
#   'created_at': {'date': '2020-09-30T01:13:15Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [1, 10]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [46, 62]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '.@JoeBiden’s racism has already been exposed. @realDonaldTrump will SLAM DUNK ON HIM! \n\nWhat’s your predictions, #joytribe? https://t.co/c0015fLHLn',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 5},
#  {'_id': '1311112681017860097',
#   'userid': '63335631',
#   'screen_name': 'Joy_Villa',
#   'created_at': {'date': '2020-09-30T01:16:37Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [44, 60]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'CHRIS WASN’T READY FOR THE DRAGON ENERGY OF @realDonaldTrump !!!',
#   'nreplyin': 5,
#   'nquotein': 0,
#   'nRTin': 29},
#  {'_id': '1311114009811316736',
#   'userid': '24787367',
#   'screen_name': 'LionelMedia',
#   'created_at': {'date': '2020-09-30T01:21:53Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [63, 79]}],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '“Will you shut up, man!” That’s it. You’ve got under his skin, @realDonaldTrump.',
#   'nreplyin': 2,
#   'nquotein': 2,
#   'nRTin': 20},
#  {'_id': '1311114259489787905',
#   'userid': '93288759',
#   'screen_name': 'twright55',
#   'created_at': {'date': '2020-09-30T01:22:53Z'},
#   'hashtags': [{'text': 'debate', 'indices': [0, 7]},
#    {'text': 'Debates2020', 'indices': [8, 20]},
#    {'text': 'MitchMcConnell', 'indices': [25, 40]},
#    {'text': 'Trump', 'indices': [81, 87]}],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '#debate #Debates2020 why #MitchMcConnell made a statement last year knowing that #Trump did nothing wrong with Ukraine phone call took articles of impeachment to the Senate Floor? To make Pence Pres? Who lobbied Mitch? Never Trumpers from BGR Group? Should they be investigated? https://t.co/40FTAP7o7g',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1311114557864267777',
#   'userid': '822491959805825027',
#   'screen_name': 'DaysLeft4Trump',
#   'created_at': {'date': '2020-09-30T01:24:04Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'KellyannePolls',
#     'name': 'Kellyanne Conway',
#     'id': 471672239,
#     'id_str': '471672239',
#     'indices': [0, 15]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [16, 32]},
#    {'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [33, 42]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-77.0387238, 38.8976805]},
#   'reply': True,
#   'in_reply_to_user_id_str': '471672239',
#   'in_reply_to_status_id_str': '1311114363558940679',
#   'in_reply_to_screen_name': 'KellyannePolls',
#   'quote': False,
#   'RT': False,
#   'text': '@KellyannePolls @realDonaldTrump @JoeBiden 3 Months, 21 Days, 15 Hours, 36 Minutes, and 36 Seconds',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 2},
#  {'_id': '1311115120773337089',
#   'userid': '822491959805825027',
#   'screen_name': 'DaysLeft4Trump',
#   'created_at': {'date': '2020-09-30T01:26:18Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'KellyannePolls',
#     'name': 'Kellyanne Conway',
#     'id': 471672239,
#     'id_str': '471672239',
#     'indices': [0, 15]},
#    {'screen_name': 'JoeBiden',
#     'name': 'Joe Biden',
#     'id': 939091,
#     'id_str': '939091',
#     'indices': [16, 25]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-77.0387238, 38.8976805]},
#   'reply': True,
#   'in_reply_to_user_id_str': '471672239',
#   'in_reply_to_status_id_str': '1311114989588156416',
#   'in_reply_to_screen_name': 'KellyannePolls',
#   'quote': False,
#   'RT': False,
#   'text': '@KellyannePolls @JoeBiden 3 Months, 21 Days, 15 Hours, 34 Minutes, and 7 Seconds',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 3},
#  {'_id': '1311115167279779841',
#   'userid': '108416118',
#   'screen_name': 'PhillyPartTwo',
#   'created_at': {'date': '2020-09-30T01:26:29Z'},
#   'hashtags': [{'text': 'Trump', 'indices': [58, 64]},
#    {'text': 'Debates2020', 'indices': [93, 105]},
#    {'text': 'Debates', 'indices': [106, 114]}],
#   'symbols': [],
#   'user_mentions': [],
#   'lang': 'en',
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'For someone who "doesn\'t care" about what the media says, #Trump seems to bring it up a lot. #Debates2020 #Debates',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1311115926071279616',
#   'userid': '822491959805825027',
#   'screen_name': 'DaysLeft4Trump',
#   'created_at': {'date': '2020-09-30T01:29:30Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'TayFromCA',
#     'name': 'Taylor Budowich',
#     'id': 1133393084807618560,
#     'id_str': '1133393084807618560',
#     'indices': [0, 10]},
#    {'screen_name': 'DonaldJTrumpJr',
#     'name': 'Donald Trump Jr.',
#     'id': 39344374,
#     'id_str': '39344374',
#     'indices': [11, 26]},
# ...
#     'id_str': '1209936918',
#     'indices': [45, 50]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-77.0387238, 38.8976805]},
#   'reply': True,
#   'in_reply_to_user_id_str': '2438831503',
#   'in_reply_to_status_id_str': '1314363005174456320',
#   'in_reply_to_screen_name': 'ChanelRion',
#   'quote': False,
#   'RT': False,
#   'text': '@ChanelRion @DonaldJTrumpJr @realDonaldTrump @OANN 3 Months, 11 Days, 1 Hour, 32 Minutes, and 51 Seconds',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1314592671143469056',
#   'userid': '822491959805825027',
#   'screen_name': 'DaysLeft4Trump',
#   'created_at': {'date': '2020-10-09T15:44:51Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'PressSec',
#     'name': 'Kayleigh McEnany',
#     'id': 818927131883356161,
#     'id_str': '818927131883356161',
#     'indices': [0, 9]},
#    {'screen_name': 'WhiteHouse',
#     'name': 'The White House',
#     'id': 822215673812119553,
#     'id_str': '822215673812119553',
#     'indices': [10, 21]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [22, 38]},
#    {'screen_name': 'WFPChief',
#     'name': 'David Beasley',
#     'id': 849183802777882624,
#     'id_str': '849183802777882624',
#     'indices': [39, 48]},
#    {'screen_name': 'IvankaTrump',
#     'name': 'Ivanka Trump',
#     'id': 52544275,
#     'id_str': '52544275',
#     'indices': [49, 61]},
#    {'screen_name': 'WFP',
#     'name': 'World Food Programme',
#     'id': 27830610,
#     'id_str': '27830610',
#     'indices': [62, 66]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-77.0387238, 38.8976805]},
#   'reply': True,
#   'in_reply_to_user_id_str': '818927131883356161',
#   'in_reply_to_status_id_str': '1314592093302644738',
#   'in_reply_to_screen_name': 'PressSec',
#   'quote': False,
#   'RT': False,
#   'text': '@PressSec @WhiteHouse @realDonaldTrump @WFPChief @IvankaTrump @WFP 3 Months, 11 Days, 1 Hour, 15 Minutes, and 32 Seconds',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1314603321857134594',
#   'userid': '1674798727',
#   'screen_name': 'gringanovelera',
#   'created_at': {'date': '2020-10-09T16:27:10Z'},
#   'hashtags': [{'text': 'AmyConeyBarrett', 'indices': [29, 45]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'GeoffRBennett',
#     'name': 'Geoff Bennett',
#     'id': 19502995,
#     'id_str': '19502995',
#     'indices': [0, 14]}],
#   'lang': 'en',
#   'reply': True,
#   'in_reply_to_user_id_str': '19502995',
#   'in_reply_to_status_id_str': '1314541053274451969',
#   'in_reply_to_screen_name': 'GeoffRBennett',
#   'quote': False,
#   'RT': False,
#   'text': '@GeoffRBennett Why shouldn’t #AmyConeyBarrett lie as much as the rest of the low-lifes in Trumpville? \nI think that the ability to  lie with ease is a major qualification for any job with #Trump.\nAnd lying to yourself is a necessity for anyone still supporting #Trump.',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314605298460495873',
#   'userid': '826549394606546946',
#   'screen_name': 'LumberjackHill',
#   'created_at': {'date': '2020-10-09T16:35:01Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-91.23452693, 43.80997695]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '@realdonaldtrump lied on 01-Nov-2018 saying "The Democrats want to, I mean, double up your taxes. In some cases, you\'ll have to pay three times what you\'re paying right now in order to get bad health care." #RepublicansAgainstTrump',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314624665747443712',
#   'userid': '409693411',
#   'screen_name': 'TimEBrutus',
#   'created_at': {'date': '2020-10-09T17:51:59Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'SenatorLoeffler',
#     'name': 'Senator Kelly Loeffler',
#     'id': 1200451909406121984,
#     'id_str': '1200451909406121984',
#     'indices': [0, 16]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [17, 33]},
#    {'screen_name': 'SpeakerPelosi',
#     'name': 'Nancy Pelosi',
#     'id': 15764644,
#     'id_str': '15764644',
#     'indices': [34, 48]}],
#   'lang': 'en',
#   'reply': True,
#   'in_reply_to_user_id_str': '1200451909406121984',
#   'in_reply_to_status_id_str': '1314279028673720325',
#   'in_reply_to_screen_name': 'SenatorLoeffler',
#   'quote': False,
#   'RT': False,
#   'text': '@SenatorLoeffler @realDonaldTrump @SpeakerPelosi Bullshit! Officially, 213,000 dead. Unofficially, 266,000 dead Americans die to yours @POTUS\n🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠\n@realDonaldTrump  #COVIDー19\n#CoronavirusPandemic #CoronavirusOutbreak leadership\n🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠🦠',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314631760014118913',
#   'userid': '822491959805825027',
#   'screen_name': 'DaysLeft4Trump',
#   'created_at': {'date': '2020-10-09T18:20:10Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'KellyannePolls',
#     'name': 'Kellyanne Conway',
#     'id': 471672239,
#     'id_str': '471672239',
#     'indices': [0, 15]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [16, 32]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-77.0387238, 38.8976805]},
#   'reply': True,
#   'in_reply_to_user_id_str': '471672239',
#   'in_reply_to_status_id_str': '1314631582704164866',
#   'in_reply_to_screen_name': 'KellyannePolls',
#   'quote': False,
#   'RT': False,
#   'text': '@KellyannePolls @realDonaldTrump 3 Months, 10 Days, 22 Hours, 40 Minutes, and 26 Seconds',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1314632730433314817',
#   'userid': '826549394606546946',
#   'screen_name': 'LumberjackHill',
#   'created_at': {'date': '2020-10-09T18:24:02Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [6, 22]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point',
#    'coordinates': [-108.55652779, 39.07171393]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Again @realdonaldtrump lied on 14-Jan-2019 saying "The government remains shut down for one reason and one reason only: The Democrats will not fund border security, our safety, our national security." #RepublicansForBiden',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314644997434560514',
#   'userid': '1654372250',
#   'screen_name': 'gavinatc',
#   'created_at': {'date': '2020-10-09T19:12:46Z'},
#   'hashtags': [{'text': 'Pathetic', 'indices': [93, 102]},
#    {'text': 'TrumpIsALoser', 'indices': [103, 117]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'lang': 'en',
#   'reply': True,
#   'in_reply_to_user_id_str': '25073877',
#   'in_reply_to_status_id_str': '1314638335055474688',
#   'in_reply_to_screen_name': 'realDonaldTrump',
#   'quote': False,
#   'RT': False,
#   'text': '@realDonaldTrump You two are the racist, conspiracy theory version of Statler &amp; Waldorf. #Pathetic #TrumpIsALoser #BidenHarris2020 https://t.co/uNexjd2K4t',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314647339982827524',
#   'userid': '645603',
#   'screen_name': 'ramtops',
#   'created_at': {'date': '2020-10-09T19:22:05Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'KarlTurnerMP',
#     'name': 'Karl Turner MP',
#     'id': 432396682,
#     'id_str': '432396682',
#     'indices': [0, 13]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [14, 30]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-0.31230846, 53.75863647]},
#   'reply': True,
#   'in_reply_to_user_id_str': '432396682',
#   'in_reply_to_status_id_str': '1314638523543191553',
#   'in_reply_to_screen_name': 'KarlTurnerMP',
#   'quote': False,
#   'RT': False,
#   'text': '@KarlTurnerMP @realDonaldTrump His medication is making him manic.',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314648281570570240',
#   'userid': '822491959805825027',
#   'screen_name': 'DaysLeft4Trump',
#   'created_at': {'date': '2020-10-09T19:25:49Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'WhiteHouse',
#     'name': 'The White House',
#     'id': 822215673812119553,
#     'id_str': '822215673812119553',
#     'indices': [0, 11]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [12, 28]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-77.0387238, 38.8976805]},
#   'reply': True,
#   'in_reply_to_user_id_str': '822215673812119553',
#   'in_reply_to_status_id_str': '1314648070496362496',
#   'in_reply_to_screen_name': 'WhiteHouse',
#   'quote': False,
#   'RT': False,
#   'text': '@WhiteHouse @realDonaldTrump 3 Months, 10 Days, 21 Hours, 34 Minutes, and 55 Seconds',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314652358521974784',
#   'userid': '826549394606546946',
#   'screen_name': 'LumberjackHill',
#   'created_at': {'date': '2020-10-09T19:42:01Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [14, 30]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-92.47562394, 44.02090457]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Remember when @realdonaldtrump lied on 08-Dec-2017 saying "Oh, these resisters resist. Hillary resisted and you know what happened? She lost the election in a landslide." #RepublicansForBiden',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314665191825498112',
#   'userid': '826549394606546946',
#   'screen_name': 'LumberjackHill',
#   'created_at': {'date': '2020-10-09T20:33:01Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [8, 24]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-91.48410648, 46.01589717]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'Another @realdonaldtrump truth fabrication on 15-Mar-2017 saying "Our trade deficit last year reached nearly 800 billion. Who\'s making these deals?" #RepublicansAgainstTrump',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314666184957218819',
#   'userid': '19405396',
#   'screen_name': 'Wonderm00n',
#   'created_at': {'date': '2020-10-09T20:36:58Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [68, 84]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-9.09202253, 38.59662458]},
#   'reply': False,
#   'quote': True,
#   'RT': False,
#   'text': 'Ladies and gentlemen: the president of the United States of America @realDonaldTrump',
#   'nreplyin': 1,
#   'nquotein': 0,
#   'nRTin': 1},
#  {'_id': '1314666198999601152',
#   'userid': '826549394606546946',
#   'screen_name': 'LumberjackHill',
#   'created_at': {'date': '2020-10-09T20:37:01Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point',
#    'coordinates': [-108.55652779, 39.07171393]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '@realdonaldtrump fabrication on 20-Mar-2019 saying "Right here in Ohio, Nucor has just announced an 85 million upgrade in Marion." #RepublicansForBiden',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314677524710912000',
#   'userid': '826549394606546946',
#   'screen_name': 'LumberjackHill',
#   'created_at': {'date': '2020-10-09T21:22:02Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [0, 16]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-105.0802052, 40.56129447]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '@realdonaldtrump lied on 05-Nov-2018 saying "And you talk about border walls, the other one (Arizona Democratic Rep. Kyrsten Sinema) doesn\'t want any border walls, she doesn\'t want any protection. Nothing." #RepublicansAgainstTrump',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314680892783308800',
#   'userid': '2931649466',
#   'screen_name': 'ElPeterSantana',
#   'created_at': {'date': '2020-10-09T21:35:25Z'},
#   'hashtags': [{'text': 'johnnyrottenapplecores', 'indices': [58, 81]}],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [27, 43]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-118.384, 34.0847]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': '@rob_rogers_cartoons draws @realdonaldtrump as what he is #johnnyrottenapplecores @ West Hollywood, California https://t.co/wS0Pn9uBM4',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314687202182471680',
#   'userid': '579356182',
#   'screen_name': 'RadioAfricaLR',
#   'created_at': {'date': '2020-10-09T22:00:29Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [46, 62]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-93.5723, 45.3115]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'We are voting by mail just because Covid-Bob. @realdonaldtrump @ Elk River, Minnesota https://t.co/Be2pwoTFdn',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314696896863244289',
#   'userid': '167830574',
#   'screen_name': 'reallykarel',
#   'created_at': {'date': '2020-10-09T22:39:00Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [4, 20]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point', 'coordinates': [-115.149, 36.1675]},
#   'reply': False,
#   'quote': False,
#   'RT': False,
#   'text': 'See @realdonaldtrump it’s not that hard. You get a test. You post the results. As of this morning. I was negative. Can you say the same? #Covid19 #gettested @ Las Vegas, Nevada https://t.co/mUh8aQ6zns',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  {'_id': '1314697636646055937',
#   'userid': '18110050',
#   'screen_name': 'pjolstead',
#   'created_at': {'date': '2020-10-09T22:41:57Z'},
#   'hashtags': [],
#   'symbols': [],
#   'user_mentions': [{'screen_name': 'SenatorDole',
#     'name': 'Senator Bob Dole',
#     'id': 3342812001,
#     'id_str': '3342812001',
#     'indices': [0, 12]},
#    {'screen_name': 'realDonaldTrump',
#     'name': 'Donald J. Trump',
#     'id': 25073877,
#     'id_str': '25073877',
#     'indices': [13, 29]}],
#   'lang': 'en',
#   'coordinates': {'type': 'Point',
#    'coordinates': [-122.59921982, 45.52703857]},
#   'reply': True,
#   'in_reply_to_user_id_str': '3342812001',
#   'in_reply_to_status_id_str': '1314657560994045952',
#   'in_reply_to_screen_name': 'SenatorDole',
#   'quote': False,
#   'RT': False,
#   'text': '@SenatorDole @realDonaldTrump “Fair”? You have to be kidding. “Fair” has left the building. Your party ushered it out.',
#   'nreplyin': 0,
#   'nquotein': 0,
#   'nRTin': 0},
#  ...]

# %%
# solución
def num_menciones(db,usuario):
    return db.tweet.count_documents({"user_mentions.screen_name": usuario})

### para probar el código
print(num_menciones(db,"JoeBiden"),"menciones a JoeBiden")
print(num_menciones(db,"realDonaldTrump"),"menciones a realDonaldTrump")
# Out:
# 453 menciones a JoeBiden
# 1479 menciones a realDonaldTrump

# %% [markdown]
# **Ejericicio 3** Escribir una función `prop_clave` para conocer la proporción de documentos que contienen una cierta clave a primer nivel en la colección tweets
# - *Nombre*: `prop_clave`
# - *Parámetros de entrada*:
#     - `db`: el acceso a una base de datos que se asume incluye una colección `tweet`de tweets
#     - `clave`: clave a comprobar
#
# - *Devuelve*: proporción sobre 1 (número entre 0 y 1) de tweets que incluyen la clave
# - Obs: se puede usar python para hacer la operación aritmética que da la proporción, no tiene sentido usar MongoDB para eso
#
# En el ejemplo se prueba la prop. de tweets que tienen coordenadas (esto es incluyen la clave 'coordinates')

# %%
# solución
def prop_clave(db,clave):
    return db.tweet.count_documents({clave: {"$exists": 1}}) / db.tweet.count_documents({})
    
print("Proporción de tweets con coordenadas",prop_clave(db,"coordinates"))
# Out:
# Proporción de tweets con coordenadas 0.6035737921906023

# %% [markdown]
# **Ejericicio 4** Escribir una función `muestra_NY(db)` que internamente utilice una consulta Mongo para obtener los tweets que se han generado entre la longitud -74.5 y -73.5 (primera coordenada), y la latitud 40.5 y 41 (segunda coordenada), con los valores extremos no incluídos, y muestre, usando folium, un mapa centrado en las coordenadas 40.75 (lat) y -74(long), con un zoom_start de 9 (lo que corresponde al área de NY), tal que al hacer click en cada tweet muestre su texto
#
# - *Nombre*: `muestra_NY(db)`
# - *Parámetros de entrada*:
#
#     - db el acceso a la base de datos
#
# - *Devuelve*: Un map de folium con la representación de los tweets en su coordenada. Al hacer click sobre un tweet se mostrará su text
#
# Debe mostrar algo parecido a esto (en el ejemplo tras hacer click en un tweet)
# ![](http://gpd.sip.ucm.es/rafa/docencia/nosql/images/ny.png)

# %%
import folium
    
# solución
def muestra_NY(db):
    m = folium.Map(location=[40.75,-74], zoom_start=9)
    for tweet in db.tweet.find({"coordinates.coordinates.0":{"$gte": -74.5, "$lte": -73.5}, "coordinates.coordinates.1":{"$gte": 40.5, "$lte": 41}},{'_id':0, 'coordinates':1, 'text':1}):
        folium.Marker([tweet["coordinates"]["coordinates"][1], tweet["coordinates"]["coordinates"][0]],
            popup=tweet['text'], tooltip="Clickame!").add_to(m)
    return m

# %%
# para probar 
muestra_NY(db)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_dab5970f0a6842adbd6ad2eaa3c46f6f%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_dab5970f0a6842adbd6ad2eaa3c46f6f%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_dab5970f0a6842adbd6ad2eaa3c46f6f%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_dab5970f0a6842adbd6ad2eaa3c46f6f%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B40.75%2C%20-74.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# **Ejercicio 5** La librería para el tratamiento de lenguaje natural `flair` incorpora, entre otras muchas utilidades una sencilla forma de hacer análisis de sentimiento.
#
# Primero, si no hemos intalado la librería debemos hacerlo

# %% [markdown]
# Aquí un pequeño ejemplo; la función `sentimiento` (que podemos usar en el ejercicio) para cada texto nos devuelve el sentimiento general y el grado de confianza en su estimación. La función recibie el clasificador (que no debemos cambiar) y la frase, y devuelve el valor y la confianza en forma de diccionario.

# %%
from flair.models import TextClassifier
from flair.data import Sentence
from flair.models import SequenceTagger

classifier = TextClassifier.load('en-sentiment')

def sentimiento(classifier, s):
    # make a sentence
    sentence = Sentence(s)
    classifier.predict(sentence)
    return sentence.labels[0].to_dict()
frase = '''Since 2016, the SEC/FBI has used 10 tax payer funded lawyers to shake me down over a 35,000 civil trade 
       dispute, all because I support @realDonaldTrump. 
       While ignoring @JoeBiden family schemes to bring billions from China, UKR &amp; Russia. 
       If I was a @TheDemocrats I’d blame RACISM! https://t.co/5rwMrGihcl'''

s = sentimiento(classifier,frase)
print("Sentimiento ",s["value"]," confianza ",s["confidence"])
# Out:
# 2021-10-13 22:34:39,388 loading file C:\Users\jorvi\.flair\models\sentiment-en-mix-distillbert_4.pt
# Sentimiento  NEGATIVE  confianza  0.9916785955429077

# %%
sentimiento(classifier, [frase, frase, frase])
# Out:
# {'value': 'NEGATIVE', 'confidence': 0.9998190999031067}

# %% [markdown]
# Escribir una función `añade_sentimiento(db,classifier,screen_name)` que modifique los tweets del usuario indicado que tengan una clave text añadiendo el sentiemiento que indica flair en una nueva clave `flair`. Además, la función devolverá el sentimiento medio del usuario sumando todas las "confidences" pero con valor negativo para las que tengan "value" "NEGATIVE", con valor positivo para las que lo tengan "POSITIVE", y con valor 0 para los que devuelvan "NEUTRAL", y dividiendo finalmente esta suma por el total de valores sumados.
#
#
# - *Nombre*: `añade_sentimiento(db,classifier,screen_name)`
# - *Parámetros de entrada*:
#
#     - db el acceso a la base de datos
#     - classifier: el clasificador flair
#     - screen_name: el screen_name de un usuario
#
# - *Devuelve*: Modifica la colección tweet añadiendo a cada documento del usuario que contenga la clave 'text' el sentimiento devuelto por flair. Además devuelve la media de las "confidences" considerando las negativas con un -, las positivas como valores positivas y las neutrales como 0
#
# Nota: la media se puede calcular sobre la marcha en Python, ya que va obteniendo cada "confidence"

# %%
# solución
def añade_sentimiento(db,classifier,screen_name): 
    sumaConfidences = 0
    for tweet in db.tweet.find({'screen_name': screen_name, 'text':{'$exists':1}}, {'_id':1, 'text':1}):
        sent = sentimiento(classifier, tweet['text'])
        db.tweet.update_one({'_id': tweet['_id']}, {'$set':{'flair': sent['value']}})
        sumaConfidences += sent['confidence'] if sent['value'] == "POSITIVE" else -sent['confidence'] if sent['value'] == "NEGATIVE" else 0
    return sumaConfidences / db.tweet.count_documents({'screen_name': screen_name, 'text':{'$exists':1}})

# %%
# para probar
db.tweet.update_many({},{"$unset":{"flair":""}})
print(añade_sentimiento(db,classifier,"realDonaldTrump"))
print(añade_sentimiento(db,classifier,"jon_kinsley"))
# Out:
# -0.2596050073271212
# 0.9064595390249182

# %%
#Para comprobar que se han hecho los updates correctamente
pprint(list(db.tweet.find({"$or":[{"screen_name":"realDonaldTrump"},{"screen_name":"jon_kinsley"}], 'text':{'$exists':1}},{"_id":0, "screen_name":1, "flair":1})))
# Out:
# [{'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'NEGATIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'jon_kinsley'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'POSITIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'},
#  {'flair': 'NEGATIVE', 'screen_name': 'realDonaldTrump'}]

# %% [markdown]
# **Ejercicio 6** Escribir una función `num_tweets(db,n)`para mostrar por pantalla el número de tweets de cada usuario de mayor a menor para todo usuario que haya escrito al menos n tweets
#
# - *Nombre*: `num_tweets(db,n)`
# - *Parámetros de entrada*:
#
#     - db el acceso a la base de datos
#     - n el número mínimo de tweets para que un usuario aparezca en e resultado
#
# - *Devuelve*: nada, solo muestra el resultado por pantalla
#
# Nota: se valorará hacerlo usando agregaciones (ver notebook pymongo-aggregaciones)

# %%
# ejercicio 6
def num_tweets(db,n):
    for tweet in db.tweet.aggregate([{'$group':{'_id':'$screen_name', 'num_tweets':{'$sum':1}}}, {'$sort':{'num_tweets':-1}}, {'$match':{'num_tweets':{'$gte':n}}}]):
        pprint(tweet)
num_tweets(db,50)
# Out:
# {'_id': 'LumberjackHill', 'num_tweets': 336}
# {'_id': 'DaysLeft4Trump', 'num_tweets': 173}
# {'_id': 'realDonaldTrump', 'num_tweets': 138}
# {'_id': 'shiffy64', 'num_tweets': 90}
# {'_id': 'pidybi', 'num_tweets': 69}
# {'_id': 'jon_kinsley', 'num_tweets': 55}

# %% [markdown]
# **Ejericicio 7**   **Difícil**
# Definir una función `cercanos(db,long,lat,maxKm)` que permite obtener una lista de los screen_name de los usuarios que se han enviado algún tweet a una distancia máxima `maxKm`de ese punto
#
# - *Nombre*: `cercanos(db,long,lat,maxKm)`
# - *Parámetros de entrada*:
#
#     - db el acceso a la base de datos
#     - long,lat: coordenadas de un punto (en el mismo formato que se usa en los tweets)
#     - Distancia máxima en la que buscar tweets
#
#
# - *Devuelve*: Una lista Python con los screen_names de los usuarios que emitieron tweets a una distancia máxima maxKM. Si algún usuario ha emitido más de un tweet con coordenadas desde menos de esa distancia, aparecerá repetido
#
# Nota: se debe hacer utilizando funciones de Mongo y aprovechando el índice de tipo GEOSPHERE

# %%
# No borrar esto; sí se pueden añadir funciones auxiliares u otros import que hagan falta a continuación
import operator
db.tweet.create_index([("coordinates", pymongo.GEOSPHERE)])

def cercanos(db,long,lat,maxKm):

    return list(map(operator.itemgetter('screen_name'), db.tweet.find({'coordinates':{'$near':{'$geometry':{"type": "Point", "coordinates": [long, lat]}, "$maxDistance": maxKm * 1000}}}, {'_id':0, 'screen_name':1})))


# Alternativa:
# list(map(operator.itemgetter('screen_name'), db.tweet.find({'coordinates':{'$geoWithin':{'$centerSphere':[[long,lat], maxKm/6378.1]}}}, {'_id':0, 'screen_name':1})))
print(cercanos(db,-117,0,5))
print(cercanos(db,-74,40.75,2.3))
# Out:
# ['HW_TRK']
# ['Brian_Atwood', 'trafficgifs', 'TimEBrutus', 'LionelMedia', 'ngalai', 'TheatreChat', 'sailorboyj', 'realDonaldTrump', 'realDonaldTrump', 'realDonaldTrump', 'realDonaldTrump', 'realDonaldTrump', 'realDonaldTrump', 'realDonaldTrump']

# %% [markdown]
# ## Parte 2 - Neo4j
#
# Estos ejercicios no los ejecutaremos en el Notebook sino en Neo4j, aquí copiaremos solo la solución
#
# Para comenzar, copiar y pegar las instrucciones para crear un [grafo de ejemplo](https://raw.githubusercontent.com/RafaelCaballero/tdm/master/datos/usa2020neo4j.txt) con usuarios que han retuiteado a otros. El grafo tendrá un aspecto similar a este:
#
# ![](http://gpd.sip.ucm.es/rafa/docencia/nosql/images/usa2020neo4j.png)
#
# Todos los nodos son de tipo Usuario, solo que algunos son además de tipo BP (Biden positivo) o TN (Trump negativo) o ambos. Las relaciones pueden ser de cualquiera de los 4 tipos que se indican en la gráfica, y van de la persona que retuitea al autor del mensaje. Es decir, si A reuitea a B se tendra una relación de la forma (A)-->(B)

# %% [markdown]
# **Nota: Hemos puesto ':Usuario' en todos los nodos de nuestras consultas porque aunque se dice que todos los nodos son usuarios, si en el futuro no fuese así nuestras consultas seguirían siendo válidas.**

# %% [markdown]
# **Ejercicio 1** Obtener todos los usuarios que han retuiteado  al usuario con atributo `id` "MichaelCohen212" (salen 5)

# %% [markdown]
# Copiar aquí la solución
#
# MATCH (U:Usuario)-->(:Usuario{id: "MichaelCohen212"}) RETURN U

# %% [markdown]
# **Ejercicio 2** Encontrar un camino de longitud 4 (4 relaciones, 5 nodos) entre los usuarios con id "CaslerNoel" y "mmpadellan". El orden de las flechas no importa, pero todas las relaciones deben ser de tipo TNegBNeu  (Trump negativo, Biden neutro)

# %% [markdown]
# Copiar aquí la solución
#
# MATCH P = (:Usuario {id:"CaslerNoel"})-[:TNegBNeu *4]-(:Usuario {id:"mmpadellan"})
# RETURN P LIMIT 1

# %% [markdown]
# **Ejercicio 3**  id del usuario con más followers

# %% [markdown]
# Copiar aquí la solución
#
# MATCH (U :Usuario)
# WITH max(U.followers) as m
# MATCH (U :Usuario {followers:m})
# RETURN U.id

# %% [markdown]
# **Ejercicio 4** Encontrar un ciclo de longitud 4 (4 relaciones, 4 nodos ya que el primero y el último son el mismo) entre el usuario id:"DHStokyo" y el mismo, de forma que los 4 nodos tengan diferentes `id`

# %% [markdown]
# Copiar aquí la solución
#
# ### Solución trivial
#
# MATCH P=(:Usuario {id:"DHStokyo"})-->(U1 :Usuario)-->(U2 :Usuario)-->(U3 :Usuario)-->(:Usuario {id:"DHStokyo"})
# WHERE U1.id <> U2.id AND U1.id <> U3.id AND U2.id <> U3.id
# RETURN P LIMIT 1
#
# ### Solución más general
